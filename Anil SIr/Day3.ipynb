# %%
name = 'Saravana Perumal R'

# %%
print(name)
# Out:
# Saravana Perumal R

# %%
len(name)
# Out:
# 18

# %%
name[0]
# Out:
# 'S'

# %%
name
# Out:
# 'Saravana Perumal R'

# %%
fname=name[0:8] #[n,n-1]
fname
# Out:
# 'Saravana'

# %%
len(name)
# Out:
# 18

# %%
name = input('enter an name')
print(f'your name is {name}, it contains {len(name)} number of charechters')
# Out:
# your name is anil, it contains 4 number of charechters

# %%
name
# Out:
# 'anil'

# %%
name
# Out:
# 'arya'

# %%
name.upper()
# Out:
# 'ANIL'

# %%
name
# Out:
# 'anil'

# %%
name = name.upper() #reassignment

# %%
name
# Out:
# 'ANIL'

# %%
s = 'Iam "saravana"'
print(s)
# Out:
# Iam "saravana"

# %%
s.count('a')
# Out:
# 5

# %%
s.index('a')
# Out:
# 1

# %%
text = "I like Java"
text.replace("Java", "Python")
# Out:
# 'I like Python'

# %%
import pandas as pd

# %%
pd.DataFrame()
