# %% [markdown]
# # List

# %%
f = ['string',12,12.5,True,None]

# %%
f
# Out:
# ['string', 12, 12.5, True, None]

# %%
f[0:2]
# Out:
# ['string', 12]

# %%
f.append('new')

# %%
f
# Out:
# ['string', 12, 12.5, True, None, 'new']

# %%
num = [1,2,3,4,5,6]

# %%
num.append(7)

# %%
num
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
num.remove(3)

# %%
num
# Out:
# [1, 2, 4, 5, 6, 7]

# %%
num.pop(0)
# Out:
# 1

# %%
num
# Out:
# [2, 4, 5, 6, 7]

# %% [markdown]
# # Tuple

# %%
g =(1,2,3,4,5,6) #immutable

# %%
type(g)
# Out:
# tuple

# %%
g.index(2)
# Out:
# 1

# %%
g.count(3)
# Out:
# 1

# %% [markdown]
# # sets

# %%
s = {1,2,3,3,3,3}

# %%
s
# Out:
# {1, 2, 3}

# %%
s2={4,5,6}

# %%
s.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# # dictionary

# %%
d = {"key":"value"}

# %%
d
# Out:
# {'key': 'value'}

# %%
type(d)
# Out:
# dict

# %%
bbx ={"c1": "Ai",
      "c2":"python"}

# %%
bbx["c1"]
# Out:
# 'Ai'

# %%
saravana ={'name': "Saravana Perumal",
          "age": 30,
          "address": "Karaman"
          }

# %%
saravan["age"]
# Out:
# 30

# %%
saravana ={'name': "Saravana Perumal",
          "age": 30,
          "address": {"home":"karamana",
                      "office": "kochi"}
          }

# %%
saravana['address']["home"]
# Out:
# 'karamana'

# %%
saravana.keys()
# Out:
# dict_keys(['name', 'age', 'address'])

# %%
saravan.values()
# Out:
# dict_values(['Saravana Perumal', 30, 'Karaman'])

# %%
saravana.

# %%
g =

# %%
g =
